# %% [markdown]
# <b> Create a class to implement the graph that have flexibilty to generate the weighted graph and simple graphs.</b>

# %% [markdown]
# After generating the class represent the following graphs using your class.

# %% [markdown]
# <b>Graph 1</b>
# ![image.png](attachment:image.png)

# %% [markdown]
# <b>Graph 2</b>
# ![image.png](attachment:image.png)

# %%
# Create Class Here
class Graph:
    def __init__(self):
        self.weighted = False
    def addVertex(self,v):
        global myGraph
        if v in myGraph:
            print(v,"already exixts in graph")
        else:
            myGraph[v] = []
    def addWeightedEdge(self,v1,v2,w):
        global myGraph
        self.weighted = True
        if v1 not in myGraph:
            print(v1,"does not exixt")
        elif v2 not in myGraph:
            print(v2,"does not exist")
        else:
            temp = [v2,w]
            myGraph[v1].append(temp)
    def addEdge(self,v1,v2):
        global myGraph
        if v1 not in myGraph:
            print(v1,"does not exixt")
        elif v2 not in myGraph:
            print(v2,"does not exist")
        else:
            temp = [v2]
            myGraph[v1].append(temp)
    def display(self):
        global myGraph
        if(self.weighted == True):
            for vertex in myGraph:
                for edges in myGraph[vertex]:
                    print(vertex, " -> ", edges[0], " edge weight: ", edges[1])
        else:
            print(myGraph)

myGraph = {}
obj = Graph()
obj.addVertex(1)
obj.addVertex(2)
obj.addVertex(3)
obj.addVertex(4)

obj.addWeightedEdge(1,2,1)
obj.addWeightedEdge(1,3,1)
obj.addWeightedEdge(2,3,3)
obj.addWeightedEdge(3,4,4)
obj.addWeightedEdge(4,1,5)

obj.display()

myGraph.clear()

obj2 = Graph()
obj2.addVertex('A')
obj2.addVertex('B')
obj2.addVertex('C')
obj2.addVertex('D')
obj2.addVertex('E')
obj2.addVertex('F')

obj2.addEdge('A','B')
obj2.addEdge('A','C')
obj2.addEdge('B','D')
obj2.addEdge('B','E')
obj2.addEdge('C','F')
obj2.display()
# Out:
# 1  ->  2  edge weight:  1
# 1  ->  3  edge weight:  1
# 2  ->  3  edge weight:  3
# 3  ->  4  edge weight:  4
# 4  ->  1  edge weight:  5
# {'A': [['B'], ['C']], 'B': [['D'], ['E']], 'C': [['F']], 'D': [], 'E': [], 'F': []}
