# %% [markdown]
# # Searching Algorithms

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Uniform Cost Search
#
# Instead of expanding the shallowest node as in BFS, uniform-cost search expands the node n with the lowest path cost g(n). This is done by storing the frontier as a priority queue ordered by g. The algorithm is shown below. At each stage, the path that has the lowest cost so far is extended. In this way, the path that is generated is likely to be the path with the lowest overall cost.
#
# UCS is different from BFS and DFS because here the costs come into play. In other words, traversing via different edges might not have the same cost. The goal is to find a path where the cumulative sum of costs is least.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Uniform Cost Search is the best algorithm for a search problem, which does not involve the use of heuristics. It can solve any general graph for optimal cost. Uniform Cost Search as it sounds searches in branches that are more or less the same in cost. The algorithm’s worst-case time and space complexity are both in O(b1+⌊C* ​⁄ ε⌋). Let C* is Cost of the optimal solution, and ε is each step to get closer to the goal node. Then the number of steps is = C*/ε+1.

# %% [markdown]
# #### Pseudocode
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Pseudocode
# ![image.png](attachment:image.png)
